# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 9960  14837  1.286884 -0.124610  0.148283 -0.259343  0.248357  0.896718
# 9961  14854  1.318742  0.496408  0.114876  0.695262  0.170133 -0.537180
# 9962  14857  1.241757  0.419587  0.806183  0.894811 -0.507886 -1.118126
# 9963  14861  1.304800 -0.052885  0.415235 -0.081725 -0.223525  0.097752
# 9964  14864 -1.747939  3.712444       NaN       NaN       NaN       NaN
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 9960 -0.626627  0.227693  1.618678  ... -0.381864 -0.904515 -0.027985
# 9961  0.025492 -0.272931  1.267298  ... -0.484943 -1.111176  0.028259
# 9962  0.018908 -0.343335  1.210781  ... -0.379396 -0.817785  0.181425
# 9963 -0.561240  0.067228  1.617203  ... -0.379597 -0.929204  0.020955
# 9964       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9965 entries, 0 to 9964
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    9965 non-null   int64
#  1   V1      9965 non-null   float64
#  2   V2      9965 non-null   float64
#  3   V3      9964 non-null   float64
#  4   V4      9964 non-null   float64
#  5   V5      9964 non-null   float64
#  6   V6      9964 non-null   float64
#  7   V7      9964 non-null   float64
#  8   V8      9964 non-null   float64
#  9   V9      9964 non-null   float64
#  10  V10     9964 non-null   float64
#  11  V11     9964 non-null   float64
#  12  V12     9964 non-null   float64
#  13  V13     9964 non-null   float64
#  14  V14     9964 non-null   float64
#  15  V15     9964 non-null   float64
#  16  V16     9964 non-null   float64
#  17  V17     9964 non-null   float64
#  18  V18     9964 non-null   float64
#  19  V19     9964 non-null   float64
# ...

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Check if 'V3' column contains numeric data
if credit_card_data['V3'].dtype == 'object':
    # Convert 'V3' column to numeric data type
    credit_card_data['V3'] = pd.to_numeric(credit_card_data['V3'])

# Fill missing values in 'V3' column with the median
credit_card_data['V3'].fillna(credit_card_data['V3'].median(), inplace=True)

# %%
if credit_card_data['V4'].dtype == 'object':
    credit_card_data['V4'] = pd.to_numeric(credit_card_data['V4'])

# Fill missing values in 'V4' column with the median
credit_card_data['V4'].fillna(credit_card_data['V4'].median(), inplace=True)

if credit_card_data['V5'].dtype == 'object':
    credit_card_data['V5'] = pd.to_numeric(credit_card_data['V5'])

# Fill missing values in 'V4' column with the median
credit_card_data['V5'].fillna(credit_card_data['V5'].median(), inplace=True)

if credit_card_data['V6'].dtype == 'object':
    credit_card_data['V6'] = pd.to_numeric(credit_card_data['V6'])

# Fill missing values in 'V4' column with the median
credit_card_data['V6'].fillna(credit_card_data['V6'].median(), inplace=True)

if credit_card_data['V7'].dtype == 'object':
    credit_card_data['V7'] = pd.to_numeric(credit_card_data['V7'])

# Fill missing values in 'V4' column with the median
credit_card_data['V7'].fillna(credit_card_data['V7'].median(), inplace=True)

# %%
if credit_card_data['V8'].dtype == 'object':
    credit_card_data['V8'] = pd.to_numeric(credit_card_data['V8'])

# Fill missing values in 'V4' column with the median
credit_card_data['V8'].fillna(credit_card_data['V8'].median(), inplace=True)

if credit_card_data['V9'].dtype == 'object':
    credit_card_data['V9'] = pd.to_numeric(credit_card_data['V9'])

# Fill missing values in 'V4' column with the median
credit_card_data['V9'].fillna(credit_card_data['V9'].median(), inplace=True)

if credit_card_data['V10'].dtype == 'object':
    credit_card_data['V10'] = pd.to_numeric(credit_card_data['V10'])

# Fill missing values in 'V4' column with the median
credit_card_data['V10'].fillna(credit_card_data['V10'].median(), inplace=True)

if credit_card_data['V11'].dtype == 'object':
    credit_card_data['V11'] = pd.to_numeric(credit_card_data['V11'])

# Fill missing values in 'V4' column with the median
credit_card_data['V11'].fillna(credit_card_data['V11'].median(), inplace=True)

if credit_card_data['V12'].dtype == 'object':
    credit_card_data['V12'] = pd.to_numeric(credit_card_data['V4'])

# Fill missing values in 'V4' column with the median
credit_card_data['V12'].fillna(credit_card_data['V12'].median(), inplace=True)

if credit_card_data['V13'].dtype == 'object':
    credit_card_data['V13'] = pd.to_numeric(credit_card_data['V13'])

# Fill missing values in 'V4' column with the median
credit_card_data['V13'].fillna(credit_card_data['V13'].median(), inplace=True)

if credit_card_data['V14'].dtype == 'object':
    credit_card_data['V14'] = pd.to_numeric(credit_card_data['V14'])

# Fill missing values in 'V4' column with the median
credit_card_data['V14'].fillna(credit_card_data['V4'].median(), inplace=True)

if credit_card_data['V15'].dtype == 'object':
    credit_card_data['V15'] = pd.to_numeric(credit_card_data['V15'])

# Fill missing values in 'V4' column with the median
credit_card_data['V15'].fillna(credit_card_data['V15'].median(), inplace=True)


if credit_card_data['V16'].dtype == 'object':
    credit_card_data['V16'] = pd.to_numeric(credit_card_data['V16'])

# Fill missing values in 'V4' column with the median
credit_card_data['V16'].fillna(credit_card_data['V16'].median(), inplace=True)

if credit_card_data['V17'].dtype == 'object':
    credit_card_data['V17'] = pd.to_numeric(credit_card_data['V17'])

# Fill missing values in 'V4' column with the median
credit_card_data['V17'].fillna(credit_card_data['V17'].median(), inplace=True)

if credit_card_data['V18'].dtype == 'object':
    credit_card_data['V18'] = pd.to_numeric(credit_card_data['V18'])

# Fill missing values in 'V4' column with the median
credit_card_data['V18'].fillna(credit_card_data['V18'].median(), inplace=True)

if credit_card_data['V19'].dtype == 'object':
    credit_card_data['V19'] = pd.to_numeric(credit_card_data['V19'])

# Fill missing values in 'V4' column with the median
credit_card_data['V19'].fillna(credit_card_data['V19'].median(), inplace=True)

if credit_card_data['V20'].dtype == 'object':
    credit_card_data['V20'] = pd.to_numeric(credit_card_data['V20'])

# Fill missing values in 'V4' column with the median
credit_card_data['V20'].fillna(credit_card_data['V20'].median(), inplace=True)

if credit_card_data['V21'].dtype == 'object':
    credit_card_data['V21'] = pd.to_numeric(credit_card_data['V21'])

# Fill missing values in 'V4' column with the median
credit_card_data['V21'].fillna(credit_card_data['V21'].median(), inplace=True)

if credit_card_data['V22'].dtype == 'object':
    credit_card_data['V22'] = pd.to_numeric(credit_card_data['V22'])

# Fill missing values in 'V4' column with the median
credit_card_data['V22'].fillna(credit_card_data['V22'].median(), inplace=True)

if credit_card_data['V23'].dtype == 'object':
    credit_card_data['V23'] = pd.to_numeric(credit_card_data['V23'])

# Fill missing values in 'V4' column with the median
credit_card_data['V23'].fillna(credit_card_data['V4'].median(), inplace=True)

if credit_card_data['V24'].dtype == 'object':
    credit_card_data['V24'] = pd.to_numeric(credit_card_data['V24'])

# Fill missing values in 'V4' column with the median
credit_card_data['V24'].fillna(credit_card_data['V4'].median(), inplace=True)

if credit_card_data['V25'].dtype == 'object':
    credit_card_data['V25'] = pd.to_numeric(credit_card_data['V25'])

# Fill missing values in 'V4' column with the median
credit_card_data['V25'].fillna(credit_card_data['V25'].median(), inplace=True)

if credit_card_data['V26'].dtype == 'object':
    credit_card_data['V26'] = pd.to_numeric(credit_card_data['V26'])

# Fill missing values in 'V4' column with the median
credit_card_data['V26'].fillna(credit_card_data['V26'].median(), inplace=True)

if credit_card_data['V27'].dtype == 'object':
    credit_card_data['V27'] = pd.to_numeric(credit_card_data['V27'])

# Fill missing values in 'V4' column with the median
credit_card_data['V27'].fillna(credit_card_data['V27'].median(), inplace=True)
if credit_card_data['V28'].dtype == 'object':
    credit_card_data['V28'] = pd.to_numeric(credit_card_data['V28'])
credit_card_data['V28'].fillna(credit_card_data['V28'].median(), inplace =  True)

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Check if 'V3' column contains numeric data
if credit_card_data['Amount'].dtype == 'object':
    # Convert 'V3' column to numeric data type
    credit_card_data['Amount'] = pd.to_numeric(credit_card_data['V3'])

# Fill missing values in 'V3' column with the median
credit_card_data['Amount'].fillna(credit_card_data['Amount'].median(), inplace=True)

# %%
# Check if 'V3' column contains numeric data
if credit_card_data['Class'].dtype == 'object':
    # Convert 'V3' column to numeric data type
    credit_card_data['Class'] = pd.to_numeric(credit_card_data['V3'])

# Fill missing values in 'V3' column with the median
credit_card_data['Class'].fillna(credit_card_data['Class'].median(), inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    9927
# 1.0      38
# Name: count, dtype: int64

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (9927, 31)
# (38, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    9927.00000
# mean       62.91477
# std       184.03263
# min         0.00000
# 25%         5.17500
# 50%        15.95000
# 75%        51.04500
# max      7712.43000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      38.000000
# mean       75.730526
# std       304.521215
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    5922.508512 -0.235729  0.267180  0.934389  0.239733 -0.041717
# 1.0    9063.157895 -1.796662  3.810809 -6.415255  5.618146 -1.247563
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.140933 -0.057633 -0.069963  0.812943  ...  0.026102 -0.055111
# 1.0   -2.111328 -3.777261  1.150469 -2.276505  ...  0.467700  0.741934
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.152006 -0.033435  0.023162  0.087543  0.107527  0.003623  0.001703
# 1.0   -0.164628 -0.024469 -0.371142  0.018063  0.310646  0.525443  0.355663
#
#           Amount
# Class
# 0.0    62.914770
# 1.0    75.730526
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 3938   3543  0.900987 -1.198726  0.391595 -2.028156 -1.079939 -0.037108
# 4230   3753  1.374181 -0.492705  0.798031 -0.360606 -1.411303 -1.236778
# 6280   7399 -0.383562  1.342420  2.054227  2.761479  0.537922  0.864263
# 1118    869 -0.603569  0.929801  0.981950  1.043636  1.014268 -1.090712
# 8394  11238 -0.770135  0.728582  2.332205  1.657901 -0.270098  0.866474
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 3938 -0.545993  0.121461  2.091281  ...  0.313900  0.895777 -0.339127
# 4230 -0.779992 -0.167912  0.831984  ... -0.247308 -0.713236  0.210067
# 6280  0.239295  0.246996 -0.471197  ... -0.253914 -0.564320 -0.039127
# 1118  0.811408 -0.409026 -0.324543  ... -0.040112  0.340829 -0.316882
# 8394  0.055864  0.252946  2.002989  ... -0.491580 -0.560827  0.105411
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#        Time        V1        V2         V3         V4        V5        V6  \
# 9035  12597 -2.589617  7.016714 -13.705407  10.343228 -2.954461 -3.055116
# 9179  13126 -2.880042  5.225442 -11.063330   6.689951 -5.759924 -2.244031
# 9252  13323 -5.454362  8.287421 -12.752811   8.594342 -3.106002 -3.179949
# 9487  14073 -4.153014  8.204797 -15.031714  10.330100 -3.994426 -3.250013
# 9509  14152 -4.710529  8.636214 -15.496222  10.313349 -4.351341 -3.322689
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 9035  -9.301289  3.349573 -5.654212  ...  1.887738  0.333998  0.287659
# 9179 -11.199975  4.014722 -3.429304  ...  2.002883  0.351102  0.795255
# 9252  -9.252794  4.245062 -6.329801  ...  1.846165 -0.267172 -0.310804
# 9487 -10.415698  4.620804 -5.711248  ...  1.976988  0.256510  0.485908
# 9509 -10.788373  5.060381 -5.689311  ...  1.990545  0.223785  0.554408
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0     38
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#               Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    5875.695122 -0.204156  0.388914  0.979267  0.267654 -0.003701
# 1.0    9063.157895 -1.796662  3.810809 -6.415255  5.618146 -1.247563
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.149579 -0.017565 -0.045331  0.793249  ...  0.033545 -0.034359
# 1.0   -2.111328 -3.777261  1.150469 -2.276505  ...  0.467700  0.741934
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.188385 -0.034112  0.007032  0.084296  0.082160  0.005008 -0.000608
# 1.0   -0.164628 -0.024469 -0.371142  0.018063  0.310646  0.525443  0.355663
#
#           Amount
# Class
# 0.0    50.763984
# 1.0    75.730526
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#        Time        V1        V2         V3         V4        V5        V6  \
# 3938   3543  0.900987 -1.198726   0.391595  -2.028156 -1.079939 -0.037108
# 4230   3753  1.374181 -0.492705   0.798031  -0.360606 -1.411303 -1.236778
# 6280   7399 -0.383562  1.342420   2.054227   2.761479  0.537922  0.864263
# 1118    869 -0.603569  0.929801   0.981950   1.043636  1.014268 -1.090712
# 8394  11238 -0.770135  0.728582   2.332205   1.657901 -0.270098  0.866474
# ...     ...       ...       ...        ...        ...       ...       ...
# 9035  12597 -2.589617  7.016714 -13.705407  10.343228 -2.954461 -3.055116
# 9179  13126 -2.880042  5.225442 -11.063330   6.689951 -5.759924 -2.244031
# 9252  13323 -5.454362  8.287421 -12.752811   8.594342 -3.106002 -3.179949
# 9487  14073 -4.153014  8.204797 -15.031714  10.330100 -3.994426 -3.250013
# 9509  14152 -4.710529  8.636214 -15.496222  10.313349 -4.351341 -3.322689
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 3938    0.0
# 4230    0.0
# 6280    0.0
# 1118    0.0
# 8394    0.0
#        ...
# 9035    1.0
# 9179    1.0
# 9252    1.0
# 9487    1.0
# 9509    1.0
# Name: Class, Length: 530, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (530, 30) (424, 30) (106, 30)

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  1.0

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  1.0
